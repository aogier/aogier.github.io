# %%
# !jupyter labextension install @iau/cy-jupyterlab
# Out:
# Node v11.9.0
#
# > /opt/conda/bin/npm pack @iau/cy-jupyterlab
# npm notice
# npm notice 📦  @iau/cy-jupyterlab@0.1.0
# npm notice === Tarball Contents ===
# npm notice 1.7kB package.json
# npm notice 505B  README.md
# npm notice 86B   lib/Components/ControlPanel/index.d.ts
# npm notice 1.6kB lib/Components/ControlPanel/index.js
# npm notice 443B  lib/Components/ControlPanel/LayoutSelector.d.ts
# npm notice 2.7kB lib/Components/ControlPanel/LayoutSelector.js
# npm notice 150B  lib/Components/ControlPanel/PropertyPanel.d.ts
# npm notice 1.0kB lib/Components/ControlPanel/PropertyPanel.js
# npm notice 431B  lib/Components/ControlPanel/SelectedPanel.d.ts
# npm notice 2.4kB lib/Components/ControlPanel/SelectedPanel.js
# npm notice 78B   lib/Components/ControlPanel/TitleBar.d.ts
# npm notice 698B  lib/Components/ControlPanel/TitleBar.js
# npm notice 438B  lib/Components/index.d.ts
# npm notice 2.4kB lib/Components/index.js
# npm notice 223B  lib/Components/NetworkPanel.d.ts
# ...
