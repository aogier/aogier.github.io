# %% [markdown]
# - title: Reply code challenge 2019 - small
# - author: Alessandro Ogier
# - date: 2019-03-16
# - category: python
# - tags: datascience,python,jupyter,cool
# - status: draft

# %% [markdown]
# # Reply code challenge 2019
#
# A data science layman approach

# %% [markdown]
# A sample exercise, taken from [contest's pdf](https://challenges.reply.com/tamtamy/file/download-99235.action) (*requires registration*).
#
# Basically: given a map representation and a list of customers coordinates, find the N most convenient places where build a base that satisfy those constraint:
#
# - cannot be built on mountains/customer cell
# - connect to at least one customer via a path made by NSEW (ie. no diagonal) moves
#
# Paths costs are the sum of cells costs (defined below). Each reached customers grant a reward `reward - moves_cost`.

# %%
rawmap = '''
####################
##_____T____##___###
####___X_#_______###
######_T_##______###
#___TXTT~~##__++__##
#___T_#~~~~##+++++_#
____T_#~~~~~#++++___
#______~~~~##+++___#
#_______~~#________#
___HHHH*HH*HHHHH*___
###__________#######
'''

customers = {(15, 1): {'reward': 1700},
             (14, 6): {'reward': 1200},
             (3, 8): {'reward': 1100},
             (17, 9): {'reward': 1050}
             }

bases_to_build = 2

# %%
tiles = {'#': {'type': 'mountains',
               'cost': 0},
         '~': {'type': 'water',
               'cost': 800},
         '*': {'type': 'traffic jam',
               'cost': 200},
         '+': {'type': 'dirt',
               'cost': 150},
         'X': {'type': 'railway level crossing',
               'cost': 120},
         '_': {'type': 'standard terrain',
               'cost': 100},
         'H': {'type': 'highway',
               'cost': 70},
         'T': {'type': 'railway',
               'cost': 50}
         }

# %% [markdown]
# Transpose the given map so we can use an (x,y) coordinate system

# %%
map = list(zip(*rawmap.split()))

# %% [markdown]
# Populate a graph with a node for every walkable tile (ie. non mountains)

# %%
import networkx as nx

G = nx.Graph()
for x in range(len(map)):
    for y in range(len(map[0])):
        if map[x][y] != '#':
            G.add_node((x, y),
                       tile=map[x][y],
                       cost=tiles[map[x][y]]['cost'])

# %% [markdown]
# Enrich the graph nodes with customers' info

# %%
# %%time

G.add_nodes_from(customers.items())
# Out:
# CPU times: user 18 µs, sys: 7 µs, total: 25 µs
# Wall time: 30.5 µs

# %% [markdown]
# Connect every walkable node with his walkable neighbours (NSEW) via an edge

# %%
# %%time

edges = []
for node in G.nodes:

    # possible NSEW neighbours' coordinates
    for x, y in [(node[0] - 1, node[1]),
                 (node[0] + 1, node[1]),
                 (node[0], node[1] + 1),
                 (node[0], node[1] - 1)]:

        try:
            # eclude mountains, negative coordinates
            if map[x][y] != '#' and not -1 in (x, y):
                edges.append((node, (x, y)))
        except IndexError:
            pass

G.add_edges_from(edges)
# Out:
# CPU times: user 2.38 ms, sys: 0 ns, total: 2.38 ms
# Wall time: 2.34 ms

# %% [markdown]
# # Let's see what have we done so far

# %%
# %%time

import scipy
import plotly.offline as py
from plotly import graph_objs as go

py.init_notebook_mode(connected=True)

pos = nx.kamada_kawai_layout(G)

edge_trace = go.Scattergl(
    x=[],
    y=[],
    line=dict(width=0.5, color='#888'),
    hoverinfo='none',
    mode='lines')

for edge in G.edges():
    x0, y0 = pos[edge[0]]
    x1, y1 = pos[edge[1]]
    edge_trace['x'] += tuple([x0, x1, None])
    edge_trace['y'] += tuple([y0, y1, None])

node_trace = go.Scattergl(
    x=[],
    y=[],
    text=[],
    mode='markers',
    hoverinfo='text',
    marker=dict(
        showscale=True,
        # colorscale options
        # 'Greys' | 'YlGnBu' | 'Greens' | 'YlOrRd' | 'Bluered' | 'RdBu' |
        # 'Reds' | 'Blues' | 'Picnic' | 'Rainbow' | 'Portland' | 'Jet' |
        # 'Hot' | 'Blackbody' | 'Earth' | 'Electric' | 'Viridis' |
        colorscale='YlGnBu',
        reversescale=True,
        color=[],
        size=[],
        colorbar=dict(
            thickness=15,
            title='Node Connections',
            xanchor='left',
            titleside='right'
        ),
        line=dict(
            width=2,
            color=[],
            colorscale='Reds'
        )))

norm = scipy.linalg.norm([x['cost'] for x in tiles.values()])
for node, data in G.nodes(data=True):
    x, y = pos[node]
    node_type = tiles[data['tile']]['type']
    node_cost = data['cost']
    if node in customers:
        node_size = 20
        ct = f'<br>CUSTOMER: {customers[node]["reward"]}'
    else:
        node_size = 10
        ct = ''

    node_trace['x'] += tuple([x])
    node_trace['y'] += tuple([y])
    node_trace['text'] += (f'{node}<br>'
                           f'type: {node_type}<br>'
                           f'cost: {node_cost}' + ct, )
    node_trace['marker']['line']['color'] += (node_cost/norm, )
    node_trace['marker']['size'] += (node_size, )

for adjacencies in G.adjacency():
    node_trace['marker']['color'] += tuple([len(adjacencies[1])])

annotations = [dict(
    x=pos[node][0],
    y=pos[node][1],
    xref='x',
    yref='y',
    text='A'

) for node, data in G.nodes(data=True)]

fig = go.Figure(data=[edge_trace, node_trace],
                layout=go.Layout(
                title='<br>Map cells adjacencies',
                titlefont=dict(size=16),
                showlegend=False,
                hovermode='closest',
                margin=dict(b=20, l=5, r=5, t=40),
                annotations=[dict(
                    text="The redder the outline, the more it costs to pass (hover for details).",
                    showarrow=False,
                    xref="paper", yref="paper",
                    x=0.005, y=-0.002)],
                xaxis=dict(showgrid=False, zeroline=False,
                           showticklabels=False),
                yaxis=dict(showgrid=False, zeroline=False, showticklabels=False)))
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# CPU times: user 2.56 s, sys: 464 ms, total: 3.03 s
# Wall time: 3.79 s

# %% [markdown]
# In this (basicly) interactive graph you see cell's transit cost (circle outline) and its adjacencies (1 to 4, obviously). Bigger nodes are customers.
#
# (*Actual graph cells are hidden for the sake of brevity if you want to see how this is made then check out pages' repo [here](https://github.com/aogier/aogier.github.io/blob/source/content/reply-cc-2019.ipynb)*)

# %%
# %%time

py.iplot(fig, filename='networkx')
# Out:
# CPU times: user 44.7 ms, sys: 67 µs, total: 44.8 ms
# Wall time: 42.9 ms

# %% [markdown]
# # Find the sweet spots

# %% [markdown]
# A graphical view already suggest, at least seems so, where to put our bases in order to maximize profit. But *where*, exactly?
#
# In the following code we check the reward for every customer starting from every possible location (ie. no mountains, no customer's cells):

# %%
# %%time

def get_weight(u, v, data):
    return G.nodes[v]['cost']


distances = nx.all_pairs_dijkstra_path(G, weight=get_weight)

for node, distance in distances:
    for customer, cdata in customers.items():
        if customer not in distance:
            # todo
            continue

        path = distance[customer][1:]
        cost = 0
        for hop in path:
            cost += G.nodes[hop]['cost']
        reward = cdata['reward'] - cost
#         print(f'{node} -> {customer}: {reward} {path}')
        nx.set_node_attributes(G, {node:
                                   {customer: {'reward': reward,
                                               'path': path}}})
# Out:
# CPU times: user 290 ms, sys: 2.97 ms, total: 293 ms
# Wall time: 293 ms

# %%
# %%time
pos = nx.kamada_kawai_layout(G)

node_trace = go.Scatter(
    x=[],
    y=[],
    text=[],
    mode='markers',
    hoverinfo='text',
    marker=dict(
        showscale=True,
        # colorscale options
        # 'Greys' | 'YlGnBu' | 'Greens' | 'YlOrRd' | 'Bluered' | 'RdBu' |
        # 'Reds' | 'Blues' | 'Picnic' | 'Rainbow' | 'Portland' | 'Jet' |
        # 'Hot' | 'Blackbody' | 'Earth' | 'Electric' | 'Viridis' |
        colorscale='Greens',
        reversescale=True,
        color=[],
        size=[],
        colorbar=dict(
            thickness=15,
            title='Rewards',
            xanchor='left',
            titleside='right'
        ),
        line=dict(
            width=2,
            color=[],
        )))

for node, data in G.nodes(data=True):
    x, y = pos[node]
    node_type = tiles[data['tile']]['type']
    node_cost = data['cost']
    if node in customers:
        reward=0
    else:
        reward = sum([v['reward']
                      for k, v
                      in data.items()
                      if isinstance(k, tuple)])
    if node in customers:
        node_size = 20
        ct = f'<br>CUSTOMER: {customers[node]["reward"]}'
    else:
        node_size = 10
        ct = ''

    node_trace['x'] += tuple([x])
    node_trace['y'] += tuple([y])
    node_trace['text'] += (f'{node}<br>{reward}' + ct, )
    node_trace['marker']['size'] += (node_size, )
    node_trace['marker']['color'] += (reward, )
    node_trace['marker']['line']['color'] += ('#F00' if reward < 0 else '#000', )

annotations = [dict(
    x=pos[node][0],
    y=pos[node][1],
    xref='x',
    yref='y',
    text='A'

) for node, data in G.nodes(data=True)]


fig = go.Figure(data=[edge_trace, node_trace],
                layout=go.Layout(
                title='<br>Map cells adjacencies',
                titlefont=dict(size=16),
                showlegend=False,
                hovermode='closest',
                margin=dict(b=20, l=5, r=5, t=40),
                annotations=[dict(
                    text="The redder the outline, the more it costs to pass (hover for details).",
                    showarrow=False,
                    xref="paper", yref="paper",
                    x=0.005, y=-0.002)],
                xaxis=dict(showgrid=False, zeroline=False,
                           showticklabels=False),
                yaxis=dict(showgrid=False, zeroline=False, showticklabels=False)))
# Out:
# CPU times: user 1.25 s, sys: 20 ms, total: 1.27 s
# Wall time: 1.33 s

# %%
py.iplot(fig, filename='networkx')

# %%
[(k, v['reward']) for k,v in G.nodes[(2,5)].items() if isinstance(k, tuple)]
# Out:
# [((15, 1), 60), ((14, 6), -630), ((3, 8), 700), ((17, 9), -750)]

# %%
[(k, v['reward']) for k,v in G.nodes[(16,7)].items() if isinstance(k, tuple)]
# Out:
# [((15, 1), 900), ((14, 6), 750), ((3, 8), -370), ((17, 9), 750)]

# %%
customers
# Out:
# {(15, 1): {'reward': 1700},
#  (14, 6): {'reward': 1200},
#  (3, 8): {'reward': 1100},
#  (17, 9): {'reward': 1050}}
